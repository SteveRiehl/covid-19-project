# %%
import pandas as pd
import numpy as np

# %%
covid['COVID-19 Deaths'].str.replace(',', '').astype(float)
# Out:
# 0        561593.0
# 1           282.0
# 2          2125.0
# 3          6165.0
# 4         16694.0
#            ...
# 87475         0.0
# 87476         0.0
# 87477         0.0
# 87478         0.0
# 87479         0.0
# Name: COVID-19 Deaths, Length: 87480, dtype: float64

# %%
covid_cases = pd.read_csv('data/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv')
# Out:
# C:\Users\Lindsey\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
covid_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24441351 entries, 0 to 24441350
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       object
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
# ...

# %%
covid_cases.head()
# Out:
#   case_month res_state  state_fips_code res_county  county_fips_code  \
# 0    2020-08       NaN              NaN        NaN               NaN
# 1    2020-08       NaN              NaN        NaN               NaN
# 2    2020-08       NaN              NaN        NaN               NaN
# 3    2020-08       NaN              NaN        NaN               NaN
# 4    2020-08       NaN              NaN        NaN               NaN
#
#   age_group  sex race ethnicity  case_positive_specimen_interval  \
# 0       NaN  NaN  NaN       NaN                              NaN
# 1       NaN  NaN  NaN       NaN                              NaN
# 2       NaN  NaN  NaN       NaN                              NaN
# 3       NaN  NaN  NaN       NaN                              0.0
# 4       NaN  NaN  NaN       NaN                              NaN
#
#    case_onset_interval  process exposure_yn             current_status  \
# 0                  NaN  Missing     Missing  Laboratory-confirmed case
# ...

# %%
covid_cases.isna().sum()
# Out:
# case_month                                0
# res_state                               679
# state_fips_code                         679
# res_county                          1788654
# county_fips_code                    1788654
# age_group                            266550
# sex                                  705216
# race                                4163723
# ethnicity                           4995992
# case_positive_specimen_interval    17752713
# case_onset_interval                13061596
# process                                   0
# exposure_yn                               0
# current_status                            0
# symptom_status                            0
# hosp_yn                                   0
# icu_yn                                    0
# death_yn                            1135531
# underlying_conditions_yn           22839680
# dtype: int64

# %%
covid_cases_nans = covid_cases.replace(['Missing', 'Unknown'], [np.nan, np.nan])

# %%
covid_cleaned = covid_cases_nans.dropna(axis=0, subset=['res_county', 'age_group', 'sex', 'race', 'ethnicity'])

# %%
covid_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10482259 entries, 869660 to 24441350
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   case_month                       object
#  1   res_state                        object
#  2   state_fips_code                  float64
#  3   res_county                       object
#  4   county_fips_code                 float64
#  5   age_group                        object
#  6   sex                              object
#  7   race                             object
#  8   ethnicity                        object
#  9   case_positive_specimen_interval  float64
#  10  case_onset_interval              float64
#  11  process                          object
#  12  exposure_yn                      object
#  13  current_status                   object
#  14  symptom_status                   object
#  15  hosp_yn                          object
# ...

# %%
covid_cleaned.head(10)
# Out:
#        case_month res_state  state_fips_code res_county  county_fips_code  \
# 869660    2021-03        NY             36.0      KINGS           36047.0
# 869661    2021-03        NY             36.0      KINGS           36047.0
# 869662    2021-03        NY             36.0      KINGS           36047.0
# 869663    2021-03        NY             36.0      KINGS           36047.0
# 869664    2021-03        NY             36.0      KINGS           36047.0
# 869665    2021-03        NY             36.0      KINGS           36047.0
# 869666    2021-03        NY             36.0      KINGS           36047.0
# 869667    2021-03        NY             36.0      KINGS           36047.0
# 869668    2021-03        NY             36.0      KINGS           36047.0
# 869669    2021-03        NY             36.0      KINGS           36047.0
#
#            age_group     sex                           race        ethnicity  \
# ...

# %%
# covid_cleaned.to_csv('./data/covid_cases_cleaned.csv')

# %%
covid_cleaned['icu_yn'].value_counts(normalize = True)
# Out:
# No     0.928653
# Yes    0.071347
# Name: icu_yn, dtype: float64

# %%
covid_cleaned['death_yn'].value_counts(normalize = True)
# Out:
# No     0.966014
# Yes    0.033986
# Name: death_yn, dtype: float64

# %%
covid_cleaned['hosp_yn'].value_counts(normalize = True)
# Out:
# No     0.877751
# Yes    0.122249
# Name: hosp_yn, dtype: float64

# %%
# icu_df = covid_cleaned.dropna(axis=0, subset=['icu_yn'])

# %%
# icu_df.to_csv('./data/icu_data.csv')

# %% [markdown]
# Group 5 Project Idea:
#
# We want to build a model that predicts whether or not a person will be admitted to a hospital because of a covid-19 infection. We will use data from the CDC website called "COVID-19 Case Surveillance Public Use Data with Geography." It includes information based on month/year of data point, geographic location, sex, age, race, symptoms, exposure, etc.
#
# Link to data source: https://data.cdc.gov/Case-Surveillance/COVID-19-Case-Surveillance-Public-Use-Data-with-Ge/n8mc-b4w4?category=Case-Surveillance&view_name=COVID-19-Case-Surveillance-Public-Use-Data-with-Ge
